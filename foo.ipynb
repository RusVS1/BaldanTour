# %%
import requests as re
HEADERS = {
    "User-Agent": "BaldanTravel"
}
foo = re.get(url = "https://api-gateway.travelata.ru/statistic/cheapestTours", headers = HEADERS)
print(foo)
# Out:
# <Response [500]>

# %%
url = "http://api-gateway.travelata.ru/directory/resorts"
response = re.get(url, headers=HEADERS)
print(response)
# Out:
# <Response [403]>

# %% [markdown]
# Получение курортов

# %%
url = "http://api-gateway.travelata.ru/directory/resorts"

# %% [markdown]
# Получение отелей

# %%
url = "http://api-gateway.travelata.ru/directory/resortHotels?resortId=1843"

# %% [markdown]
# Получение категорий отеля

# %%
url = "http://api-gateway.travelata.ru/directory/hotelCategories"

# %% [markdown]
# {
#             "id": 1,
#             "name": "1*"
#         },
#         {
#             "id": 2,
#             "name": "2*"
#         },
#         {
#             "id": 3,
#             "name": "3*"
#         },
#         {
#             "id": 4,
#             "name": "4*"
#         },
#         {
#             "id": 5,
#             "name": "Апартаменты"
#         },
#         {
#             "id": 6,
#             "name": "Вилла"
#         },
#         {
#             "id": 7,
#             "name": "5*"
#         },
#         {
#             "id": 8,
#             "name": "5* (HV-1)"
#         },
#         {
#             "id": 9,
#             "name": "4* (HV-2)"
#         },
#         {
#             "id": 10,
#             "name": "Хостел"
#         },
#         {
#             "id": 11,
#             "name": "Виллы"
#         },
#         {
#             "id": 12,
#             "name": "Клубный отель"
#         },
#         {
#             "id": 13,
#             "name": "Апарт-отель"
#         },
#         {
#             "id": 14,
#             "name": "Гостиничный комп"
#         },
#         {
#             "id": 15,
#             "name": "Курортный город"
#         },
#         {
#             "id": 16,
#             "name": "Санаторий"
#         },
#         {
#             "id": 17,
#             "name": "Пансионат"
#         },
#         {
#             "id": 18,
#             "name": "Дом отдыха"
#         },
#         {
#             "id": 19,
#             "name": "База отдыха"
#         },
#         {
#             "id": 20,
#             "name": "Гостевой дом"
#         },
#         {
#             "id": 21,
#             "name": "Гостиница"
#         },
#         {
#             "id": 22,
#             "name": "Бутик-отель"
#         },
#         {
#             "id": 23,
#             "name": "Экскурсионная программа"
#         }

# %% [markdown]
# Получение типов питания
# id
# name

# %%
url = "http://api-gateway.travelata.ru/directory/meals"

# %% [markdown]
# Получение стран
# id
# name
# popular

# %%
url = "http://api-gateway.travelata.ru/directory/countries"

# %% [markdown]
# Получение туров

# %% [markdown]
# https://api-gateway.travelata.ru/statistic/cheapestTours
# ?countries[]=92 id страны тура
# &departureCity=2 айди города вылета
# &nightRange[from]=4 минимальное количество ночей
# &resorts[]=2175 массив желаемых курортов
# &nightRange[to]=10 максимальное количество ночей
# &touristGroup[adults]=2 количество взрослых
# &touristGroup[kids]=0 количество детей
# &touristGroup[infants]=0 количество младенцев
# &hotelCategories[]=2 категория отеля
# &hotelCategories[]=7
# &ratingMin = 2 минимальный рейтинг отеля
# &ratingMin = 4 максимальный рейтинг отеля
# &checkInDateRange[from]=2026-02-13 периоды заселения дат
# &checkInDateRange[to]=2026-02-20
# "data": [
#         {
#             "tourIdentity": "ulHelbi9iU4dj/9DPjeMmTOBgvXglYJgHeH7dYMmpvbG04JLyXE7OpWyLF2jK4Qc9KddgIKuwU01VHtkacGz",
#             "price": 61013,
#             "publishedAt": "2026-02-08 12:17:59",
#             "checkinDate": "2026-02-13",
#             "nights": 4,
#             "hotelId": 49587,
#             "mealId": 1,
#             "operatorId": 26,
#             "resortId": 2175,
#             "expired": "2026-02-08 13:17:57",
#             "tourPageUrl": "https://travelata.ru/hotel/49587/tourPage?identity=ulHelbi9iU4dj%2F9DPjeMmTOBgvXglYJgHeH7dYMmpvbG04JLyXE7OpWyLF2jK4Qc9KddgIKuwU01VHtkacGz",
#             "searchPageUrl": "https://travelata.ru/search#?fromCity=2&toCountry=92&toCity=2175&dateFrom=10.02.2026&dateTo=16.02.2026&nightFrom=4&nightTo=10&adults=2&kids=0&infants=0&hotelClass=2.7&meal=all",
#             "hotelName": "Viking Star",
#             "hotelCategory": 7,
#             "hotelCategoryName": "5*",
#             "hotelRating": "4.52261",
#             "hotelPreview": "//edge.travelatacdn.ru/thumbs/640x480/upload/2025_30/content_hotel_6884ca092e0d97.40538675.webp"
#         },
#         {
